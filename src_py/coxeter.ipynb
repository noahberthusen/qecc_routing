# %%
F.<o,p> = FreeGroup()
G = F / [o^2, p^4, (o*p)^2]
G
# Out:
# Finitely presented group < o, p | o^2, p^4, o*p*o*p >

# %%
G.relations()
# Out:
# (o^2, p^4, o*p*o*p)

# %%
K = DihedralGroup(4)
sgs = K.conjugacy_classes_subgroups()
for sg in sgs:
    print(len(sg), sg)
# Out:
# 1 Subgroup generated by [()] of (Dihedral group of order 8 as a permutation group)
# 2 Subgroup generated by [(1,3)(2,4)] of (Dihedral group of order 8 as a permutation group)
# 2 Subgroup generated by [(2,4)] of (Dihedral group of order 8 as a permutation group)
# 2 Subgroup generated by [(1,2)(3,4)] of (Dihedral group of order 8 as a permutation group)
# 4 Subgroup generated by [(2,4), (1,3)(2,4)] of (Dihedral group of order 8 as a permutation group)
# 4 Subgroup generated by [(1,2,3,4), (1,3)(2,4)] of (Dihedral group of order 8 as a permutation group)
# 4 Subgroup generated by [(1,2)(3,4), (1,3)(2,4)] of (Dihedral group of order 8 as a permutation group)
# 8 Subgroup generated by [(2,4), (1,2,3,4), (1,3)(2,4)] of (Dihedral group of order 8 as a permutation group)

# %%
D = groups.presentation.Dihedral(4)
D
# Out:
# Finitely presented group < a, b | a^4, b^2, a*b*a*b >

# %%
D.as_permutation_group()
# Out:
# Permutation Group with generators [(1,2,5,3)(4,7,8,6), (1,4)(2,6)(3,7)(5,8)]

# %%
"""

f := FreeGroup("p", "q");; g := f / [f.1^8, f.2^3, (f.1*f.2)^2];; p := g.1;; q := g.2;; li := LowIndexSubgroupsFpGroupIterator(g, 10);;

while (IsDoneIterator(li) = false) do
    h := NextIterator(li);;
    if IsNormal(g, h) then
        GeneratorsOfGroup(h);;
        Print(h);
    fi;
od;

"""
